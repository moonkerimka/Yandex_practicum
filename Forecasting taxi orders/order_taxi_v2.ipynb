# %% [markdown]
# Привет, меня зовут Артем Хуршудов. Сегодня я проверю твой проект.
# <br> Дальнейшее общение будет происходить на "ты" если это не вызывает никаких проблем.
# <br> Желательно реагировать на каждый мой комментарий ('исправил', 'не понятно как исправить ошибку', ...)
# <br> Пожалуйста, не удаляй комментарии ревьюера, так как они повышают качество повторного ревью.
#
# Комментарии будут в <font color='green'>зеленой</font>, <font color='blue'>синей</font> или <font color='red'>красной</font> рамках:
#
# <div class="alert alert-block alert-success">
# <b>Успех:</b> Если все сделано отлично
# </div>
#
# <div class="alert alert-block alert-info">
# <b>Совет: </b> Если можно немного улучшить
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Ошибка:</b> Если требуются исправления. Работа не может быть принята с красными комментариями.
# </div>
#
# -------------------
#
# Будет очень хорошо, если ты будешь помечать свои действия следующим образом:
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента:</b> ...
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Изменения:</b> Были внесены следующие изменения ...
# </div>
#
# #### <font color='orange'>Полезные ссылки:</font>
# * Полезная лекция про временные ряды: https://www.youtube.com/watch?v=u433nrxdf5k .
#
# ### <font color='orange'>Общее впечатление</font>
# * Большое спасибо за проделанную работу. Видно, что приложено много усилий.
# * Отлично, что ноутбук хорошо структурирован. Приятно проверять такие работы.
# * Над этим проектом нужно будет еще немного поработать. Однако, изменения не должны занять много времени.
# * В работе я оставил несколько советов. Буду рад, если ты учтешь их.
# * С радостью отвечу на твои вопросы, если они есть. Лучше всего их собрать в следующей ячейке. Жду новую версию проекта.

# %% [markdown]
# ### <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#294B8E; font-size:140%; text-align:left;padding: 0px; border-bottom: 3px solid #294B8E">🚕 Прогнозирование заказов такси</p>

# %% [markdown]
# <a id="1.2"></a>
# <div style="padding:20px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#294B8E;
#             overflow:hidden;
#             font-weight:700"><span style='color:#CDA63A'>|</span> Содержание</div>

# %% [markdown]
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание данных</a></span></li>
#     <li><span><a href="#Загрузка-библиотек" data-toc-modified-id="Загрузка-библиотек-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Загрузка библиотек</a></span></li>
#     <li><span><a href="#EDA" data-toc-modified-id="EDA-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>EDA</a></span></li>
#     <li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Анализ данных</a></span></li>
#      <li><span><a href="#Создание-признаков" data-toc-modified-id="Создание-признаков-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Создание признаков</a></span></li>
#     <li><span><a href="#Подготовим-выборки-для-обучения-моделей" data-toc-modified-id="Подготовим-выборки-для-обучения-моделей-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Подготовим выборки для обучения моделей</a></span></li>
#     <li><span><a href="#Обучение-моделей" data-toc-modified-id="Обучение-моделей-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Обучение моделей</a></span></li>
#     <li><span><a href="#Сравнение-моделей" data-toc-modified-id="Сравнение-моделей-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Сравнение моделей</a></span></li>
#     <li><span><a href="#Тестирование-лучшей-модели" data-toc-modified-id="Тестирование-лучшей-моделей-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Тестирование лучшей модели</a></span></li>
#     <li><span><a href="#Вывод" data-toc-modified-id="Вывод-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Вывод</a></span></li>

# %% [markdown]
# <a id="Описание-данных"></a>
# <div style="padding:20px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#294B8E;
#             overflow:hidden;
#             font-weight:700"><span style='color:#CDA63A'>|</span> Описание данных</div>

# %% [markdown]
# <ul>
# <li>num_orders — количество заказов</li>
# </ul>

# %% [markdown]
# <div class="alert alert-block alert-info" style="background-color:#FFFAF0;
#                                                  color:black;
#                                                  border-color:#DEB887;
#                                                  border-radius:5px;
#                                                  width:50%;
#                                                  margin: auto;
#                                                  text-align: left;">
#
#
# Компания «Чётенькое такси» собрала исторические данные о заказах такси в аэропортах. Чтобы привлекать больше водителей в период пиковой нагрузки, нужно спрогнозировать количество заказов такси на следующий час.
#
# </div>

# %% [markdown]
# <a id="Загрузка-библиотек"></a>
# <div style="padding:20px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#294B8E;
#             overflow:hidden;
#             font-weight:700"><span style='color:#CDA63A'>|</span> Загрузка библиотек</div>

# %%
import os
import time
import warnings
import pandas as pd
import numpy as np
import catboost as cb
import lightgbm as lgmb
import matplotlib.pyplot as plt 
from sklearn import tree, metrics
from tabulate import tabulate
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from statsmodels.tsa.stattools import adfuller
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.model_selection import GridSearchCV, train_test_split, TimeSeriesSplit

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех:</b> Отлично, что все импорты собраны в первой ячейке ноутбука! Если у того, кто будет запускать твой ноутбук будут отсутствовать некоторые библиотеки, то он это увидит сразу, а не в процессе!
# </div>

# %% [markdown]
# <a id="EDA"></a>
# <div style="padding:20px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#294B8E;
#             overflow:hidden;
#             font-weight:700"><span style='color:#CDA63A'>|</span> EDA</div>

# %%
pth1 = '/datasets/taxi.csv'
pth2 = 'taxi.csv'
if os.path.exists(pth1):
    data = pd.read_csv(pth1, index_col=[0], parse_dates=[0])
elif os.path.exists(pth2):
    data = pd.read_csv(pth2, index_col=[0], parse_dates=[0])
else:
    print('Something is wrong')

# %%
data.head()
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00           9
# 2018-03-01 00:10:00          14
# 2018-03-01 00:20:00          28
# 2018-03-01 00:30:00          20
# 2018-03-01 00:40:00          32

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 26496 entries, 2018-03-01 00:00:00 to 2018-08-31 23:50:00
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  26496 non-null  int64
# dtypes: int64(1)
# memory usage: 414.0 KB

# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:left">
#     В данных отсутствуют пропуски.

# %%
#ресемеплирование по одному часу
data.sort_index(inplace=True)
data = data.resample('1H').sum()
# Построение графика
plt.title("Количество заказов") # заголовок
plt.xlabel("Дата") # ось абсцисс
plt.ylabel("Количество заказов") # ось ординат
plt.grid()      # включение отображение сетки
plt.plot(data['num_orders']);  # построение графика

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Ошибка:</b> Во всех графиках в проекте нужно подписать оси и названия, чтобы было понятно, что на нем визуализировано.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Изменения:</b> Были внесены следующие изменения: В графиках подписаны оси и названия.
# </div>

# %%
data['mean'] = data['num_orders'].rolling(15).mean()
data['std'] = data['num_orders'].rolling(15).std()
plt.title("Количество заказов с марта по сентябрь 2018 года") # заголовок
plt.xlabel("Дата") # ось абсцисс
plt.ylabel("Количество заказов") # ось ординат
plt.grid()      # включение отображение сетки
plt.plot(data['num_orders'], label='Количество заказов');  # построение графика
plt.plot(data['mean'], label='Среднее значение временного ряда');  # построение графика
plt.plot(data['std'], label='Стандартное отклонение временного ряда');  # построение графика
plt.legend();

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех:</b> Данные загружены корректно, первичный осмотр проведен. Ресемплинг был сделан верно.
# </div>

# %%
pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /Users/moonkerimka/opt/anaconda3/lib/python3.9/site-packages (0.13.2)
# Requirement already satisfied: numpy>=1.17 in /Users/moonkerimka/opt/anaconda3/lib/python3.9/site-packages (from statsmodels) (1.21.5)
# Requirement already satisfied: packaging>=21.3 in /Users/moonkerimka/opt/anaconda3/lib/python3.9/site-packages (from statsmodels) (21.3)
# Requirement already satisfied: scipy>=1.3 in /Users/moonkerimka/opt/anaconda3/lib/python3.9/site-packages (from statsmodels) (1.9.1)
# Requirement already satisfied: pandas>=0.25 in /Users/moonkerimka/opt/anaconda3/lib/python3.9/site-packages (from statsmodels) (1.4.4)
# Requirement already satisfied: patsy>=0.5.2 in /Users/moonkerimka/opt/anaconda3/lib/python3.9/site-packages (from statsmodels) (0.5.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/moonkerimka/opt/anaconda3/lib/python3.9/site-packages (from packaging>=21.3->statsmodels) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/moonkerimka/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/moonkerimka/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.25->statsmodels) (2022.1)
# Requirement already satisfied: six in /Users/moonkerimka/opt/anaconda3/lib/python3.9/site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:left">
#     Проверим, является ли временной ряд стационарным, выполним расширенный тест Дики-Фуллера, в котором используются следующие нулевая и альтернативная гипотезы:
# <br>H0: Временной ряд является нестационарным. Другими словами, он имеет некоторую структуру, зависящую от времени, и не имеет постоянной дисперсии во времени.
# <br>H1: Временной ряд является стационарным.

# %%
p_value = adfuller(data['num_orders'])[1]
print('p =', p_value)
if p_value < 0.05:
    print('Нулевая гипотеза отвергается. Ряд стационарен по расширеннему тесту Дики-Фуллера')
else:
    print('Нулевая гипотеза не отвергается. Ряд нестационарен по расширеннему тесту Дики-Фуллера')
# Out:
# p = 0.028940051402613316
# Нулевая гипотеза отвергается. Ряд стационарен по расширеннему тесту Дики-Фуллера

# %% [markdown]
# <div class="alert alert-block alert-info" style="background-color:#FFFAF0;
#                                                  color:black;
#                                                  border-color:#DEB887;
#                                                  border-radius:5px;
#                                                  width:50%;
#                                                  margin: auto;
#                                                  text-align: left;">
#
# <b>✍ Вывод</b>
# <br>В данных не обнаружены пропуски. Проведено ресемеплирование по одному часу. Временной ряд стационарен.
# </div>

# %% [markdown]
# <a id="Анализ-данных"></a>
# <div style="padding:20px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#294B8E;
#             overflow:hidden;
#             font-weight:700"><span style='color:#CDA63A'>|</span> Анализ данных</div>

# %%
data = data.drop(columns=['mean', 'std'])

# %%
decomposed = seasonal_decompose(data)

# %%
plt.title("Сезонность") 
plt.ylabel("Количество заказов") 
plt.grid()      
decomposed.seasonal['2018-08-01':'2018-08-31'].plot(figsize=(15,3))
plt.title('Сезонность')
plt.show()

# %%
plt.title("Тренд")
plt.ylabel("Количество заказов") 
plt.grid()      
decomposed.trend.plot(figsize=(15,3));

# %%
plt.title("Остатки")
plt.xlabel("Дата") 
plt.ylabel("Количество заказов") 
plt.grid()      
decomposed.resid.plot(figsize=(15,3));

# %% [markdown]
# <div class="alert alert-block alert-info" style="background-color:#FFFAF0;
#                                                  color:black;
#                                                  border-color:#DEB887;
#                                                  border-radius:5px;
#                                                  width:50%;
#                                                  margin: auto;
#                                                  text-align: left;">
#
# <b>✍ Вывод</b>
#         <ul>
# <li>Данные разложены на три составляющие: сезонность, тренд и остаток.</li>
# <li>Трэнд показывает линейный рост количества заказов со временем.</li>
#
# </ul>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех:</b> Декомпозиция была сделана верно.
# </div>
#
# <div class="alert alert-block alert-info">
# <b>Совет: </b> Однако, желательно чтобы сезонность была визуализирована на более коротком интервале!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Изменения:</b> Были внесены следующие изменения: сезонность была визуализирована на более коротком интервале.
# </div>

# %% [markdown]
# <a id="Создание-признаков"></a>
# <div style="padding:20px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#294B8E;
#             overflow:hidden;
#             font-weight:700"><span style='color:#CDA63A'>|</span> Создание признаков</div>

# %%
def make_features(data, max_lag, rolling_mean_size):
    data['year'] = data.index.year
    data['month'] = data.index.month
    data['day'] = data.index.day
    data['dayofweek'] = data.index.dayofweek
    
    for lag in range(1, max_lag + 1):
        data['lag_{}'.format(lag)] = data['num_orders'].shift(lag)

    data['rolling_mean'] = data['num_orders'].shift().rolling(rolling_mean_size).mean()
    data_taxi = data
    return data_taxi

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <b>Совет: </b> Желательно было написать функцию таким образом, чтобы она возвращала новый датафрейм, а не изменяла глобальную переменную.
# 1. Это хорошая практика (не изменять глобальные переменные внутри функции), которая улучшает читаемость кода.
# 2. В какой-то момент может появиться необходимость подбирать некоторые параметры используемый внутри функции. В этот момент копирование датасета станет обязательным.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Изменения:</b> Были внесены следующие изменения: функция возвращает новый датафрейм.
# </div>

# %%
data_taxi = make_features(data, 90, 40)

# %% [markdown]
# <div class="alert alert-block alert-info" style="background-color:#FFFAF0;
#                                                  color:black;
#                                                  border-color:#DEB887;
#                                                  border-radius:5px;
#                                                  width:50%;
#                                                  margin: auto;
#                                                  text-align: left;">
#
# <b>✍ Вывод</b>
#         <ul>
# <li>Созданы календарные признаки, "отстающие значения", скользящее среднее. </li>
#
# </ul>
# </div>

# %% [markdown]
# <a id="Подготовим-выборки-для-обучения-моделей"></a>
# <div style="padding:20px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#294B8E;
#             overflow:hidden;
#             font-weight:700"><span style='color:#CDA63A'>|</span> Подготовим выборки для обучения моделей</div>

# %%
train, test_1 = train_test_split(data_taxi, shuffle=False, test_size=0.2, random_state=42)
valid, test = train_test_split(test_1, shuffle=False, test_size=0.5, random_state=42)
train = train.dropna()
X_train = train.drop('num_orders', axis=1)
y_train = train['num_orders']
X_valid = valid.drop('num_orders', axis=1)
y_valid = valid['num_orders']
X_test = test.drop('num_orders', axis=1)
y_test = test['num_orders']

# %%
print(f"Размер обучающей выборки: {X_train.shape}")

print(f"Размер валидационной выборки: {X_valid.shape}")

print(f"Размер тестовой  выборки: {X_test.shape}")
# Out:
# Размер обучающей выборки: (3442, 95)
# Размер валидационной выборки: (442, 95)
# Размер тестовой  выборки: (442, 95)

# %% [markdown]
# <div class="alert alert-block alert-info" style="background-color:#FFFAF0;
#                                                  color:black;
#                                                  border-color:#DEB887;
#                                                  border-radius:5px;
#                                                  width:50%;
#                                                  margin: auto;
#                                                  text-align: left;">
#
# <b>✍ Вывод</b>
#         <ul>
# <li>Данные разделены на обучающую, валидационную и тестовую выборки.</li>
#
# </ul>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех:</b> Разбиение было сделано корректно.
# </div>

# %% [markdown]
# <a id="Обучение-моделей"></a>
# <div style="padding:20px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#294B8E;
#             overflow:hidden;
#             font-weight:700"><span style='color:#CDA63A'>|</span> Обучение моделей</div>

# %% [markdown]
# ### <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#294B8E; font-size:140%; text-align:left;padding: 0px; border-bottom: 3px solid #294B8E">CatBoost</p>

# %%
#кроссвалидацию делаем с помощью специального инструмента:
tscv = TimeSeriesSplit(n_splits=4)

# %%
# parametrs_Cat = {'depth': [4,7,10],
#                   'learning_rate': [0.03, 0.1, 0.15],
#                   'iterations': [100, 200, 300]
#                }

# cb = cb.CatBoostRegressor(random_state=12345);

# grid_search = GridSearchCV(cb, 
#                             parametrs_Cat, 
#                             cv=tscv,  
#                             n_jobs=-1);

# grid_search.fit(X_train, y_train);

# %%
# grid_search.best_params_

# %%
# pred = grid_search.best_estimator_.predict(X_valid)

# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:left">
#     Для экономии времени будем использовать лучшие гиперпараметры.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Ошибка:</b> При работе с временными рядами нельзя использовать стандартную кросс-валидацию, так как в определенный момент тренировочная выборка окажется позже валидационной. Для решения этой проблемы стоит использовать <a href="https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.TimeSeriesSplit.html">TimeSeriesSplit</a>. Объект этого типа можно передать в параметр cv в метод основанный на кросс-валидации.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Изменения:</b> Были внесены следующие изменения: использован TimeSeriesSplit в методе основанном на кросс-валидации.
# </div>

# %%
cb = CatBoostRegressor(random_state=12345, depth=4, learning_rate=0.1, iterations=300);
cb.fit(X_train, y_train);
pred = cb.predict(X_valid)
# Out:
# 0:	learn: 34.0447422	total: 64.6ms	remaining: 19.3s
# 1:	learn: 32.6601485	total: 66.6ms	remaining: 9.93s
# 2:	learn: 31.4283036	total: 68.1ms	remaining: 6.74s
# 3:	learn: 30.2076639	total: 69.5ms	remaining: 5.15s
# 4:	learn: 29.2675555	total: 71.2ms	remaining: 4.2s
# 5:	learn: 28.4383393	total: 72.8ms	remaining: 3.57s
# 6:	learn: 27.6764833	total: 74.3ms	remaining: 3.11s
# 7:	learn: 26.9718765	total: 75.6ms	remaining: 2.76s
# 8:	learn: 26.4188896	total: 77.1ms	remaining: 2.49s
# 9:	learn: 25.8355266	total: 78.5ms	remaining: 2.28s
# 10:	learn: 25.3778609	total: 80.3ms	remaining: 2.11s
# 11:	learn: 24.9573760	total: 82ms	remaining: 1.97s
# 12:	learn: 24.5965625	total: 83.8ms	remaining: 1.85s
# 13:	learn: 24.2496351	total: 85.5ms	remaining: 1.75s
# 14:	learn: 23.9791572	total: 87.2ms	remaining: 1.66s
# 15:	learn: 23.7060684	total: 89.1ms	remaining: 1.58s
# 16:	learn: 23.4912202	total: 91.4ms	remaining: 1.52s
# 17:	learn: 23.2539583	total: 93ms	remaining: 1.46s
# 18:	learn: 23.0784661	total: 94.6ms	remaining: 1.4s
# 19:	learn: 22.9145882	total: 96.2ms	remaining: 1.35s
# 20:	learn: 22.7550461	total: 98ms	remaining: 1.3s
# 21:	learn: 22.6264102	total: 99.9ms	remaining: 1.26s
# 22:	learn: 22.4958143	total: 102ms	remaining: 1.22s
# 23:	learn: 22.3874832	total: 103ms	remaining: 1.19s
# 24:	learn: 22.3023792	total: 105ms	remaining: 1.15s
# 25:	learn: 22.1943806	total: 106ms	remaining: 1.12s
# 26:	learn: 22.1081173	total: 108ms	remaining: 1.09s
# 27:	learn: 22.0093648	total: 110ms	remaining: 1.07s
# 28:	learn: 21.9205998	total: 111ms	remaining: 1.04s
# 29:	learn: 21.8562017	total: 113ms	remaining: 1.02s
# 30:	learn: 21.8050333	total: 115ms	remaining: 994ms
# 31:	learn: 21.7666693	total: 116ms	remaining: 975ms
# 32:	learn: 21.6884949	total: 118ms	remaining: 954ms
# 33:	learn: 21.5951109	total: 120ms	remaining: 935ms
# 34:	learn: 21.5367845	total: 122ms	remaining: 920ms
# 35:	learn: 21.4865175	total: 123ms	remaining: 904ms
# 36:	learn: 21.4213970	total: 125ms	remaining: 889ms
# 37:	learn: 21.3631054	total: 127ms	remaining: 875ms
# 38:	learn: 21.3022171	total: 129ms	remaining: 864ms
# 39:	learn: 21.2761532	total: 131ms	remaining: 849ms
# 40:	learn: 21.2114822	total: 132ms	remaining: 835ms
# 41:	learn: 21.1828466	total: 134ms	remaining: 822ms
# 42:	learn: 21.1250936	total: 135ms	remaining: 808ms
# 43:	learn: 21.0714936	total: 137ms	remaining: 796ms
# 44:	learn: 21.0113287	total: 139ms	remaining: 785ms
# 45:	learn: 20.9804215	total: 140ms	remaining: 774ms
# 46:	learn: 20.9282373	total: 142ms	remaining: 764ms
# 47:	learn: 20.8838772	total: 143ms	remaining: 753ms
# 48:	learn: 20.8613554	total: 145ms	remaining: 743ms
# 49:	learn: 20.8405856	total: 147ms	remaining: 733ms
# 50:	learn: 20.8089572	total: 149ms	remaining: 725ms
# 51:	learn: 20.7945276	total: 150ms	remaining: 717ms
# 52:	learn: 20.7437486	total: 152ms	remaining: 709ms
# 53:	learn: 20.7109823	total: 154ms	remaining: 701ms
# 54:	learn: 20.6823299	total: 156ms	remaining: 695ms
# 55:	learn: 20.6509266	total: 158ms	remaining: 688ms
# 56:	learn: 20.6264089	total: 160ms	remaining: 681ms
# 57:	learn: 20.6098424	total: 162ms	remaining: 674ms
# 58:	learn: 20.6009707	total: 163ms	remaining: 666ms
# 59:	learn: 20.5742046	total: 165ms	remaining: 658ms
# 60:	learn: 20.5364210	total: 166ms	remaining: 651ms
# 61:	learn: 20.5018325	total: 168ms	remaining: 644ms
# 62:	learn: 20.4680382	total: 170ms	remaining: 641ms
# 63:	learn: 20.4332900	total: 172ms	remaining: 633ms
# 64:	learn: 20.3880377	total: 173ms	remaining: 626ms
# 65:	learn: 20.3720162	total: 175ms	remaining: 621ms
# 66:	learn: 20.3454392	total: 177ms	remaining: 615ms
# 67:	learn: 20.3154052	total: 178ms	remaining: 609ms
# 68:	learn: 20.2820987	total: 180ms	remaining: 604ms
# 69:	learn: 20.2385059	total: 182ms	remaining: 598ms
# 70:	learn: 20.1984486	total: 183ms	remaining: 592ms
# 71:	learn: 20.1676182	total: 185ms	remaining: 586ms
# 72:	learn: 20.1415869	total: 187ms	remaining: 582ms
# 73:	learn: 20.1223882	total: 189ms	remaining: 576ms
# 74:	learn: 20.0977053	total: 190ms	remaining: 571ms
# 75:	learn: 20.0863062	total: 192ms	remaining: 567ms
# 76:	learn: 20.0584978	total: 194ms	remaining: 562ms
# 77:	learn: 20.0335209	total: 196ms	remaining: 557ms
# 78:	learn: 20.0287884	total: 197ms	remaining: 552ms
# 79:	learn: 20.0196390	total: 199ms	remaining: 547ms
# 80:	learn: 19.9877444	total: 200ms	remaining: 542ms
# 81:	learn: 19.9518141	total: 202ms	remaining: 537ms
# 82:	learn: 19.9178210	total: 204ms	remaining: 533ms
# 83:	learn: 19.8873451	total: 205ms	remaining: 528ms
# 84:	learn: 19.8610432	total: 207ms	remaining: 523ms
# 85:	learn: 19.8318872	total: 209ms	remaining: 519ms
# 86:	learn: 19.8033161	total: 211ms	remaining: 518ms
# 87:	learn: 19.7696653	total: 213ms	remaining: 513ms
# 88:	learn: 19.7203426	total: 215ms	remaining: 509ms
# 89:	learn: 19.6985485	total: 216ms	remaining: 505ms
# 90:	learn: 19.6847707	total: 219ms	remaining: 502ms
# 91:	learn: 19.6396314	total: 221ms	remaining: 499ms
# 92:	learn: 19.6227901	total: 222ms	remaining: 494ms
# 93:	learn: 19.5813794	total: 224ms	remaining: 491ms
# 94:	learn: 19.5633825	total: 226ms	remaining: 487ms
# 95:	learn: 19.5353113	total: 227ms	remaining: 483ms
# 96:	learn: 19.5275220	total: 229ms	remaining: 480ms
# 97:	learn: 19.4889668	total: 231ms	remaining: 476ms
# 98:	learn: 19.4595577	total: 233ms	remaining: 472ms
# 99:	learn: 19.4334369	total: 235ms	remaining: 470ms
# 100:	learn: 19.4284660	total: 236ms	remaining: 466ms
# 101:	learn: 19.3937612	total: 238ms	remaining: 462ms
# 102:	learn: 19.3565589	total: 240ms	remaining: 458ms
# 103:	learn: 19.3231816	total: 241ms	remaining: 454ms
# 104:	learn: 19.3181421	total: 243ms	remaining: 451ms
# 105:	learn: 19.2714730	total: 244ms	remaining: 447ms
# 106:	learn: 19.2508802	total: 246ms	remaining: 443ms
# 107:	learn: 19.2053328	total: 247ms	remaining: 440ms
# 108:	learn: 19.1656867	total: 249ms	remaining: 436ms
# 109:	learn: 19.1544136	total: 250ms	remaining: 433ms
# 110:	learn: 19.1356924	total: 252ms	remaining: 429ms
# 111:	learn: 19.1284506	total: 254ms	remaining: 426ms
# 112:	learn: 19.1082493	total: 256ms	remaining: 423ms
# 113:	learn: 19.0810232	total: 257ms	remaining: 420ms
# 114:	learn: 19.0469355	total: 259ms	remaining: 417ms
# 115:	learn: 19.0244982	total: 261ms	remaining: 414ms
# 116:	learn: 18.9942255	total: 263ms	remaining: 412ms
# 117:	learn: 18.9909300	total: 265ms	remaining: 409ms
# 118:	learn: 18.9725237	total: 267ms	remaining: 406ms
# 119:	learn: 18.9601156	total: 269ms	remaining: 403ms
# 120:	learn: 18.9309906	total: 270ms	remaining: 399ms
# 121:	learn: 18.8999189	total: 272ms	remaining: 396ms
# 122:	learn: 18.8559422	total: 273ms	remaining: 394ms
# 123:	learn: 18.8527906	total: 275ms	remaining: 390ms
# 124:	learn: 18.8305305	total: 277ms	remaining: 387ms
# 125:	learn: 18.8251088	total: 278ms	remaining: 384ms
# 126:	learn: 18.7870205	total: 280ms	remaining: 381ms
# 127:	learn: 18.7493990	total: 282ms	remaining: 379ms
# 128:	learn: 18.7201143	total: 283ms	remaining: 376ms
# 129:	learn: 18.7159224	total: 286ms	remaining: 374ms
# 130:	learn: 18.6902669	total: 288ms	remaining: 371ms
# 131:	learn: 18.6598662	total: 289ms	remaining: 368ms
# 132:	learn: 18.6554039	total: 291ms	remaining: 365ms
# 133:	learn: 18.6314534	total: 292ms	remaining: 362ms
# 134:	learn: 18.6038561	total: 294ms	remaining: 360ms
# 135:	learn: 18.5477120	total: 296ms	remaining: 357ms
# 136:	learn: 18.5406001	total: 297ms	remaining: 354ms
# 137:	learn: 18.5139065	total: 299ms	remaining: 351ms
# 138:	learn: 18.4937045	total: 301ms	remaining: 348ms
# 139:	learn: 18.4554677	total: 302ms	remaining: 345ms
# 140:	learn: 18.4529741	total: 304ms	remaining: 343ms
# 141:	learn: 18.4253448	total: 306ms	remaining: 340ms
# 142:	learn: 18.4102862	total: 308ms	remaining: 338ms
# 143:	learn: 18.3887507	total: 309ms	remaining: 335ms
# 144:	learn: 18.3570106	total: 312ms	remaining: 333ms
# 145:	learn: 18.3385491	total: 313ms	remaining: 330ms
# 146:	learn: 18.3103848	total: 314ms	remaining: 327ms
# 147:	learn: 18.2855994	total: 316ms	remaining: 324ms
# 148:	learn: 18.2554160	total: 318ms	remaining: 322ms
# 149:	learn: 18.2292269	total: 320ms	remaining: 320ms
# 150:	learn: 18.2011937	total: 322ms	remaining: 318ms
# 151:	learn: 18.1725199	total: 324ms	remaining: 315ms
# 152:	learn: 18.1438767	total: 326ms	remaining: 313ms
# 153:	learn: 18.1379389	total: 327ms	remaining: 310ms
# 154:	learn: 18.1278976	total: 329ms	remaining: 307ms
# 155:	learn: 18.0902523	total: 330ms	remaining: 305ms
# 156:	learn: 18.0601645	total: 332ms	remaining: 302ms
# 157:	learn: 18.0392282	total: 334ms	remaining: 300ms
# 158:	learn: 18.0342214	total: 335ms	remaining: 297ms
# 159:	learn: 18.0017413	total: 337ms	remaining: 295ms
# 160:	learn: 17.9750583	total: 339ms	remaining: 293ms
# 161:	learn: 17.9469790	total: 341ms	remaining: 290ms
# 162:	learn: 17.9264659	total: 343ms	remaining: 288ms
# 163:	learn: 17.9047647	total: 345ms	remaining: 286ms
# 164:	learn: 17.8807793	total: 347ms	remaining: 284ms
# 165:	learn: 17.8553017	total: 348ms	remaining: 281ms
# 166:	learn: 17.8406638	total: 350ms	remaining: 279ms
# 167:	learn: 17.8140891	total: 351ms	remaining: 276ms
# 168:	learn: 17.7891238	total: 353ms	remaining: 274ms
# 169:	learn: 17.7653046	total: 355ms	remaining: 271ms
# 170:	learn: 17.7367170	total: 356ms	remaining: 269ms
# 171:	learn: 17.7159787	total: 358ms	remaining: 266ms
# 172:	learn: 17.6909059	total: 360ms	remaining: 264ms
# 173:	learn: 17.6677533	total: 362ms	remaining: 262ms
# 174:	learn: 17.6489283	total: 363ms	remaining: 260ms
# 175:	learn: 17.6356244	total: 365ms	remaining: 257ms
# 176:	learn: 17.6023277	total: 367ms	remaining: 255ms
# 177:	learn: 17.5818446	total: 368ms	remaining: 252ms
# 178:	learn: 17.5634806	total: 370ms	remaining: 250ms
# 179:	learn: 17.5467160	total: 372ms	remaining: 248ms
# 180:	learn: 17.5041717	total: 374ms	remaining: 246ms
# 181:	learn: 17.4806420	total: 376ms	remaining: 243ms
# 182:	learn: 17.4509038	total: 377ms	remaining: 241ms
# 183:	learn: 17.4461560	total: 380ms	remaining: 240ms
# 184:	learn: 17.4251934	total: 382ms	remaining: 237ms
# 185:	learn: 17.4151815	total: 384ms	remaining: 235ms
# 186:	learn: 17.3890761	total: 385ms	remaining: 233ms
# 187:	learn: 17.3706270	total: 387ms	remaining: 230ms
# 188:	learn: 17.3608622	total: 388ms	remaining: 228ms
# 189:	learn: 17.3267672	total: 390ms	remaining: 226ms
# 190:	learn: 17.3038398	total: 392ms	remaining: 224ms
# 191:	learn: 17.2873664	total: 394ms	remaining: 221ms
# 192:	learn: 17.2648778	total: 395ms	remaining: 219ms
# 193:	learn: 17.2423680	total: 397ms	remaining: 217ms
# 194:	learn: 17.2378114	total: 398ms	remaining: 214ms
# 195:	learn: 17.2254218	total: 400ms	remaining: 212ms
# 196:	learn: 17.2047420	total: 402ms	remaining: 210ms
# 197:	learn: 17.1849313	total: 403ms	remaining: 208ms
# 198:	learn: 17.1602948	total: 405ms	remaining: 206ms
# 199:	learn: 17.1299227	total: 407ms	remaining: 203ms
# 200:	learn: 17.1175177	total: 408ms	remaining: 201ms
# 201:	learn: 17.1026311	total: 410ms	remaining: 199ms
# 202:	learn: 17.1003863	total: 412ms	remaining: 197ms
# 203:	learn: 17.0776432	total: 413ms	remaining: 194ms
# 204:	learn: 17.0586579	total: 416ms	remaining: 193ms
# 205:	learn: 17.0349741	total: 418ms	remaining: 191ms
# 206:	learn: 17.0150847	total: 420ms	remaining: 188ms
# 207:	learn: 16.9909034	total: 421ms	remaining: 186ms
# 208:	learn: 16.9692222	total: 423ms	remaining: 184ms
# 209:	learn: 16.9481239	total: 424ms	remaining: 182ms
# 210:	learn: 16.9268809	total: 426ms	remaining: 180ms
# 211:	learn: 16.9026085	total: 428ms	remaining: 178ms
# 212:	learn: 16.8738018	total: 430ms	remaining: 175ms
# 213:	learn: 16.8555562	total: 431ms	remaining: 173ms
# 214:	learn: 16.8370113	total: 433ms	remaining: 171ms
# 215:	learn: 16.8195644	total: 434ms	remaining: 169ms
# 216:	learn: 16.8048748	total: 436ms	remaining: 167ms
# 217:	learn: 16.7832831	total: 438ms	remaining: 165ms
# 218:	learn: 16.7681408	total: 439ms	remaining: 163ms
# 219:	learn: 16.7633909	total: 441ms	remaining: 160ms
# 220:	learn: 16.7481194	total: 443ms	remaining: 158ms
# 221:	learn: 16.7359092	total: 444ms	remaining: 156ms
# 222:	learn: 16.7149243	total: 446ms	remaining: 154ms
# 223:	learn: 16.6955422	total: 448ms	remaining: 152ms
# 224:	learn: 16.6628104	total: 449ms	remaining: 150ms
# 225:	learn: 16.6396002	total: 451ms	remaining: 148ms
# 226:	learn: 16.6222745	total: 453ms	remaining: 146ms
# 227:	learn: 16.6031667	total: 455ms	remaining: 144ms
# 228:	learn: 16.5905583	total: 456ms	remaining: 141ms
# 229:	learn: 16.5874983	total: 459ms	remaining: 140ms
# 230:	learn: 16.5674797	total: 461ms	remaining: 138ms
# 231:	learn: 16.5494461	total: 463ms	remaining: 136ms
# 232:	learn: 16.5308573	total: 465ms	remaining: 134ms
# 233:	learn: 16.5250704	total: 466ms	remaining: 132ms
# 234:	learn: 16.5127218	total: 468ms	remaining: 129ms
# 235:	learn: 16.5092640	total: 471ms	remaining: 128ms
# 236:	learn: 16.4863117	total: 472ms	remaining: 126ms
# 237:	learn: 16.4735483	total: 474ms	remaining: 123ms
# 238:	learn: 16.4492151	total: 476ms	remaining: 121ms
# 239:	learn: 16.4352632	total: 477ms	remaining: 119ms
# 240:	learn: 16.4068360	total: 479ms	remaining: 117ms
# 241:	learn: 16.3917273	total: 481ms	remaining: 115ms
# 242:	learn: 16.3730810	total: 482ms	remaining: 113ms
# 243:	learn: 16.3669066	total: 484ms	remaining: 111ms
# 244:	learn: 16.3474528	total: 485ms	remaining: 109ms
# 245:	learn: 16.3336628	total: 487ms	remaining: 107ms
# 246:	learn: 16.3236860	total: 489ms	remaining: 105ms
# 247:	learn: 16.2955731	total: 491ms	remaining: 103ms
# 248:	learn: 16.2748042	total: 492ms	remaining: 101ms
# 249:	learn: 16.2514617	total: 494ms	remaining: 98.9ms
# 250:	learn: 16.2269923	total: 496ms	remaining: 96.9ms
# 251:	learn: 16.2122794	total: 498ms	remaining: 94.8ms
# 252:	learn: 16.1992615	total: 500ms	remaining: 92.8ms
# 253:	learn: 16.1771477	total: 501ms	remaining: 90.8ms
# 254:	learn: 16.1545904	total: 503ms	remaining: 88.8ms
# 255:	learn: 16.1361366	total: 505ms	remaining: 86.8ms
# 256:	learn: 16.1167796	total: 507ms	remaining: 84.8ms
# 257:	learn: 16.0987403	total: 508ms	remaining: 82.7ms
# 258:	learn: 16.0859347	total: 511ms	remaining: 80.9ms
# 259:	learn: 16.0750140	total: 513ms	remaining: 78.9ms
# 260:	learn: 16.0504273	total: 515ms	remaining: 76.9ms
# 261:	learn: 16.0451345	total: 517ms	remaining: 75.1ms
# 262:	learn: 16.0258169	total: 519ms	remaining: 73ms
# 263:	learn: 16.0161498	total: 521ms	remaining: 71ms
# 264:	learn: 16.0045794	total: 522ms	remaining: 69ms
# 265:	learn: 15.9896314	total: 524ms	remaining: 67ms
# 266:	learn: 15.9690571	total: 526ms	remaining: 65ms
# 267:	learn: 15.9538160	total: 528ms	remaining: 63ms
# 268:	learn: 15.9404439	total: 530ms	remaining: 61.1ms
# 269:	learn: 15.9331885	total: 533ms	remaining: 59.2ms
# 270:	learn: 15.9143886	total: 535ms	remaining: 57.3ms
# 271:	learn: 15.8947918	total: 537ms	remaining: 55.3ms
# 272:	learn: 15.8774940	total: 540ms	remaining: 53.4ms
# 273:	learn: 15.8522382	total: 543ms	remaining: 51.5ms
# 274:	learn: 15.8404583	total: 545ms	remaining: 49.6ms
# 275:	learn: 15.8230946	total: 548ms	remaining: 47.7ms
# 276:	learn: 15.7970097	total: 550ms	remaining: 45.7ms
# 277:	learn: 15.7870285	total: 552ms	remaining: 43.6ms
# 278:	learn: 15.7745008	total: 553ms	remaining: 41.7ms
# 279:	learn: 15.7564623	total: 556ms	remaining: 39.7ms
# 280:	learn: 15.7519336	total: 558ms	remaining: 37.7ms
# 281:	learn: 15.7374218	total: 559ms	remaining: 35.7ms
# 282:	learn: 15.7166556	total: 561ms	remaining: 33.7ms
# 283:	learn: 15.7033020	total: 563ms	remaining: 31.7ms
# 284:	learn: 15.6780674	total: 565ms	remaining: 29.7ms
# 285:	learn: 15.6661894	total: 567ms	remaining: 27.7ms
# 286:	learn: 15.6493500	total: 569ms	remaining: 25.8ms
# 287:	learn: 15.6265877	total: 571ms	remaining: 23.8ms
# 288:	learn: 15.6124527	total: 573ms	remaining: 21.8ms
# 289:	learn: 15.5939489	total: 575ms	remaining: 19.8ms
# 290:	learn: 15.5755570	total: 577ms	remaining: 17.8ms
# 291:	learn: 15.5548667	total: 579ms	remaining: 15.9ms
# 292:	learn: 15.5368740	total: 581ms	remaining: 13.9ms
# 293:	learn: 15.5243249	total: 583ms	remaining: 11.9ms
# 294:	learn: 15.5065017	total: 585ms	remaining: 9.91ms
# 295:	learn: 15.4992301	total: 587ms	remaining: 7.93ms
# 296:	learn: 15.4831454	total: 589ms	remaining: 5.95ms
# 297:	learn: 15.4570587	total: 590ms	remaining: 3.96ms
# 298:	learn: 15.4432790	total: 592ms	remaining: 1.98ms
# 299:	learn: 15.4311028	total: 594ms	remaining: 0us

# %%
mse_cat = mean_squared_error(y_valid, pred)
rmse_cat = (mse_cat) ** 0.5
print('RMSE для CatBoost модели на валидационной выборке: ',rmse_cat)
# Out:
# RMSE для CatBoost модели на валидационной выборке:  31.07814572129843

# %% [markdown]
# ### <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#294B8E; font-size:140%; text-align:left;padding: 0px; border-bottom: 3px solid #294B8E">XGBoost</p>

# %%
xgb = XGBRegressor(random_state=12345, learning_rate=0.1, max_depth=35)
xgb.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=35, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=12345, ...)

# %%
preds_xgb= xgb.predict(X_valid)

# %%
mse_xgb = mean_squared_error(y_valid, preds_xgb)
rmse_xgb = mse_xgb** 0.5
print('RMSE для XGBoost модели на валидационной выборке: ', rmse_xgb)
# Out:
# RMSE для XGBoost модели на валидационной выборке:  34.56975824042725

# %% [markdown]
# ### <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#294B8E; font-size:140%; text-align:left;padding: 0px; border-bottom: 3px solid #294B8E">LightGBM</p>

# %%
param_light = {'learning_rate': [0.1, 0.3, 0.5, 0.7],
               'max_depth': [15, 20, 30, 35],
              }

lgbm = LGBMRegressor(random_state = 12345)

#инициализируем GridSearchCV
grid_search = GridSearchCV(estimator = lgbm, 
                            param_grid = param_light, 
                            cv = tscv,
                            n_jobs = -1
                           );
grid_search.fit(X_train, y_train);

# %%
grid_search.best_params_
# Out:
# {'learning_rate': 0.1, 'max_depth': 15}

# %%
preds_lgbm = grid_search.best_estimator_.predict(X_valid)

# %%
mse_lgbm = mean_squared_error(y_valid, preds_lgbm)
rmse_lgbm = mse_lgbm** 0.5
print('RMSE для LightGBM модели на валидационной выборке: ', rmse_lgbm)
# Out:
# RMSE для LightGBM модели на валидационной выборке:  30.910914961990674

# %% [markdown]
# ### <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#294B8E; font-size:140%; text-align:left;padding: 0px; border-bottom: 3px solid #294B8E">DecisionTree</p>

# %%
parametrs_DT = {'max_depth': [35, 80]}

DT = DecisionTreeRegressor(random_state=12345)

#инициализируем GridSearchCV
grid_search = GridSearchCV(DT, 
                             parametrs_DT, 
                             scoring='neg_mean_squared_error', 
                             cv=tscv
                            )
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=4, test_size=None),
#              estimator=DecisionTreeRegressor(random_state=12345),
#              param_grid={'max_depth': [35, 80]},
#              scoring='neg_mean_squared_error')

# %%
grid_search.best_params_
# Out:
# {'max_depth': 35}

# %%
preds_DT = grid_search.best_estimator_.predict(X_valid)

# %%
mse_DT = mean_squared_error(y_valid, preds_DT)
rmse_DT = (mse_DT) ** 0.5
print('RMSE для Decision Tree модели на валидационной выборке: ',rmse_DT)
# Out:
# RMSE для Decision Tree модели на валидационной выборке:  45.41468058535349

# %% [markdown]
# ### <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#294B8E; font-size:140%; text-align:left;padding: 0px; border-bottom: 3px solid #294B8E">RandomForest</p>

# %%
# parametrs_RF = {'max_depth': [35, 80],
#                 'n_estimators': [80, 100]}

# RF = RandomForestRegressor(random_state=12345)

# # #инициализируем GridSearchCV
# grid_search = GridSearchCV(RF, 
#                               parametrs_RF, 
#                               scoring='neg_mean_squared_error', 
#                               cv=tscv
#                              )
# grid_search.fit(X_train, y_train)

# %%
# grid_search.best_params_

# %%
# preds_RF = grid_search.best_estimator_.predict(X_valid)

# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:left">
#     Для экономии времени будем использовать лучшие гиперпараметры.

# %%
RF = RandomForestRegressor(random_state=12345, max_depth=35, n_estimators=80)
RF.fit(X_train, y_train)
preds_RF = RF.predict(X_valid)

# %%
mse_RF = mean_squared_error(y_valid, preds_RF)
rmse_RF = (mse_RF) ** 0.5
print('RMSE для Random Forest модели на валидационной выборке: ',rmse_RF)

# %% [markdown]
# ### <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#294B8E; font-size:140%; text-align:left;padding: 0px; border-bottom: 3px solid #294B8E">LinearRegression</p>

# %%
LR = LinearRegression()
LR.fit(X_train, y_train)

# %%
pred_LR = LR.predict(X_valid)

# %%
mse_LR = mean_squared_error(y_valid, pred_LR)
rmse_LR = (mse_LR) ** 0.5
print('RMSE для Linear Regresion модели на валидационной выборке: ', rmse_LR)

# %% [markdown]
# ### <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#294B8E; font-size:140%; text-align:left;padding: 0px; border-bottom: 3px solid #294B8E">Lasso Regression</p>

# %%
lasso_model = Lasso(alpha=1.0)
lasso=lasso_model.fit(X_train , y_train)

# %%
lasso_predict = lasso.predict(X_valid)

# %%
mse_lasso = mean_squared_error(y_valid, lasso_predict)
rmse_lasso = (mse_lasso) ** 0.5
print('RMSE для Lasso Regresion модели на валидационной выборке: ', rmse_lasso)

# %% [markdown]
# ### <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#294B8E; font-size:140%; text-align:left;padding: 0px; border-bottom: 3px solid #294B8E">Ridge Regression</p>

# %%
ridge_model = Ridge(alpha=1.0)
ridge=ridge_model.fit(X_train , y_train)

# %%
ridge_predict = ridge.predict(X_valid)

# %%
mse_ridge = mean_squared_error(y_valid, ridge_predict)
rmse_ridge = (mse_ridge) ** 0.5
print('RMSE для Ridge Regresion модели на валидационной выборке: ', rmse_ridge)

# %% [markdown]
# <a id="Сравнение-моделей"></a>
# <div style="padding:20px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#294B8E;
#             overflow:hidden;
#             font-weight:700"><span style='color:#CDA63A'>|</span> Сравнение моделей</div>

# %% [markdown]
# ### <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#294B8E; font-size:140%; text-align:left;padding: 0px; border-bottom: 3px solid #294B8E">Oценка качества моделей с помощью метрики RMSE</p>

# %%
data_RMSE={'Models':['XGBoost','LightGBM','CatBoost', 'Decision Tree', 'Random Forest','Linear Regresion', 'Lasso Regresion','Ridge Regresion'],
      'RMSE': [rmse_xgb, rmse_lgbm, rmse_cat, rmse_DT, rmse_RF, rmse_LR, rmse_lasso, rmse_ridge]}
df_RMSE=pd.DataFrame(data_RMSE)
print(tabulate(df_RMSE, headers='keys', tablefmt='psql'))

# %% [markdown]
# <div class="alert alert-block alert-info" style="background-color:#FFFAF0;
#                                                  color:black;
#                                                  border-color:#DEB887;
#                                                  border-radius:5px;
#                                                  width:50%;
#                                                  margin: auto;
#                                                  text-align: left;">
#
# <b>✍ Вывод</b>
#         <ul>
# <li>Лучшей моделью является Lasso Regresion, т.к. имеет самый низкий RMSE. </li>
# <li>Из исследований следует вывод, что самая высокое RMSE у Decision Tree при тестировании на валидационной выборке. </li>
# <li>XGBoost, Random Forest, LightGBM, CatBoost, Linear Regresion, Ridge Regresion показали хорошие результаты, т.к. их метрика была меньше 48. </li>
# <li>Протестируем лучшую модель на тестовой выборке.</li>
# </ul>
# </div>

# %% [markdown]
# <a id="Тестирование-лучшей-модели"></a>
# <div style="padding:20px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#294B8E;
#             overflow:hidden;
#             font-weight:700"><span style='color:#CDA63A'>|</span> Тестирование лучшей модели</div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех:</b> Молодец, что попробовала разные модели в этом шаге!
# </div>

# %% [markdown]
# ### <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#294B8E; font-size:140%; text-align:left;padding: 0px; border-bottom: 3px solid #294B8E">Lasso Regression</p>

# %%
lasso_model = Lasso(alpha=1.0)
lasso=lasso_model.fit(X_train , y_train)

# %%
lasso_final_predict = lasso.predict(X_test)

# %%
mse_final_lasso = mean_squared_error(y_test, lasso_final_predict)
rmse_final_lasso = (mse_final_lasso) ** 0.5
print('RMSE на тестовой выборкее: ', rmse_final_lasso)

# %%
plt.title("Сравнение исходного и предсказанного ряда") 
plt.xlabel("Дата") 
plt.ylabel("Количество заказов") 
plt.grid()     
plt.plot(np.array(y_test), label='Исходный ряд');  
plt.plot(lasso_final_predict, label='Предсказанный ряд');  
plt.legend();

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Ошибка:</b> На тестовой выборке нужно измерить только одну – лучшую модель. Сравнение моделей нужно провести только на кросс-валидации (с одним и тем же параметром "cv") или только на валидационной выборке.
# </div>
#
# <div class="alert alert-block alert-info">
# <b>Совет: </b> Финальные предсказания можно было визуализирвоать: графики исходного и предсказанных рядов.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Изменения:</b> Были внесены следующие изменения: графики исходного и предсказанных рядов визуализированы. Выбрана лучшая модель.
# </div>

# %% [markdown]
# <a id="Вывод"></a>
# <div style="padding:20px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#294B8E;
#             overflow:hidden;
#             font-weight:700"><span style='color:#CDA63A'>|</span> Вывод</div>

# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:left">
# <br>📑Было проведено исследование, для<b> прогнозирования заказов такси</b>.
#
#
# <br><b> Входные данные - исторические данные о заказах такси в аэропортах. </b>
#
#
# <br> 📊 Временной ряд является стационарным. Трэнд показывает линейный рост количества заказов со временем.
#
# <br> 📊 Были обучены модели линейной регрессии, случайного леса, дерево решений, XGBoost, CatBoost, LightGBM, лассо-регрессия и гребневая регрессия.
#
# <br> 📊 Найден лучшие гиперпараметры для соотвествующих моделей с помощью GridSearchCV.
#
# <br> 📊 Показано сравнение качества исследованных моделей с помощью метрики RMSE на валидационной выборке.
#
# <br>Исходя из анализа, сделан вывод:
#         <br>             <b>- самой лучшей моделью с меньшей RMSE является лассо-регрессия.</b>
# <br>             <b>- удшей моделью стали модели градиентного бустинга и Decision Tree.
